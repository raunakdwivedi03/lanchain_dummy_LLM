# %% [markdown]
# <a href="https://colab.research.google.com/github/raunakdwivedi03/lanchain_dummy_LLM/blob/main/Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class LLM:

    def __init__(self):
        print('LLM created')

    def predict(self, prompt):
        response_list = [
            'Delhi is the capital of India',
            'IPL is the best cricket league',
            'London is the capital of England'
        ]

        return {'response': random.choice(response_list)}

# %%
llm=LLM()
# Out:
# LLM created

# %%
llm.predict('what is the capital of india')
# Out:
# {'response': 'London is the capital of England'}

# %%
class PromptTemplate:

  def __init__(self,template,input_variables):
    self.template=template
    self.input_variables=input_variables

  def fromat(self,input_dict):
    return self.template.format(**input_dict)

# %%
template =PromptTemplate(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
prompt= template.fromat({'length':'short','topic':'india'})

# %%
llm=LLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'London is the capital of England'}

# %%
class LLMchain:

  def __init__(self,llm,prompt):
    self.llm=llm
    self.prompt=prompt

  def run(self,input_dict):
    final_prompt=self.prompt.fromat(input_dict)
    result=self.llm.predict(final_prompt)

    return result['response']

# %%
template =PromptTemplate(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
llm=LLM()
# Out:
# LLM created

# %%
chain=LLMchain(llm,template)

# %%
chain.run({'length':'short','topic':'india'})
# Out:
# 'Delhi is the capital of India'
